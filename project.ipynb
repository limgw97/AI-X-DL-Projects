# %%
import os
import numpy as np
import librosa
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
def extract_mel(file_path, sr=16000, n_mels=64):
    y, _ = librosa.load(file_path, sr=sr)
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    mel_norm = (mel_db + 40) / 40  # 정규화: [-40, 0] dB → [0, 1]
    return mel_norm

# %%
def extract_mel(file_path, sr=16000, n_mels=64):
    y, _ = librosa.load(file_path, sr=sr)
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    mel_norm = (mel_db + 40) / 40
    return mel_norm

root_dir = r"D:\AI+XDL\dataset\fan"  # fan 폴더의 상위 경로

mel_data_array = []
label_array = []

for machine_id in os.listdir(root_dir):
    id_path = os.path.join(root_dir, machine_id)
    if not os.path.isdir(id_path):
        continue

    for status in ['normal', 'abnormal']:
        status_path = os.path.join(id_path, status)
        if not os.path.isdir(status_path):
            continue

        label = 0 if status == 'normal' else 1

        for file in os.listdir(status_path):
            if file.endswith(".wav"):
                file_path = os.path.join(status_path, file)
                mel = extract_mel(file_path)
                mel_data_array.append(mel)
                label_array.append(label)

mel_data_array = np.array(mel_data_array)
label_array = np.array(label_array)

print(f"Loaded {len(label_array)} samples")
# Out:
# Loaded 5550 samples

# %%
class MelSpectrogramDataset(Dataset):
    def __init__(self, mel_list, label_list):
        self.mel_list = mel_list
        self.label_list = label_list

    def __len__(self):
        return len(self.mel_list)

    def __getitem__(self, idx):
        mel = self.mel_list[idx]
        label = self.label_list[idx]

        mel_tensor = torch.tensor(mel, dtype=torch.float32)
        label_tensor = torch.tensor(label, dtype=torch.long)

        return mel_tensor, label_tensor

# %%
dataset = MelSpectrogramDataset(mel_data_array, label_array)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
class CRNN(nn.Module):
    def __init__(self, input_shape, n_classes):
        super(CRNN, self).__init__()

        self.cnn = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        dummy_input = torch.zeros(1, 1, *input_shape)
        cnn_out = self.cnn(dummy_input)
        _, c, f, t = cnn_out.shape
        self.rnn_input_size = f * c

        self.rnn = nn.LSTM(self.rnn_input_size, 64, batch_first=True, bidirectional=True)

        self.classifier = nn.Sequential(
            nn.Linear(64 * 2, 64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, n_classes)
        )

    def forward(self, x):
        x = self.cnn(x)
        x = x.permute(0, 3, 1, 2)  # (B, T, C, F)
        x = x.contiguous().view(x.shape[0], x.shape[1], -1)
        x, _ = self.rnn(x)
        x = x[:, -1, :]
        return self.classifier(x)

# %%
model = CRNN(input_shape=(64, mel_data_array.shape[2]), n_classes=2)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
num_epochs = 30

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for mel, label in dataloader:
        mel = mel.unsqueeze(1)  # (B, 1, 64, T)
        output = model(mel)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss:.4f}")
# Out:
# Epoch 1/30, Loss: 98.6494
# Epoch 2/30, Loss: 91.2964
# Epoch 3/30, Loss: 80.4827
# Epoch 4/30, Loss: 72.4535
# Epoch 5/30, Loss: 64.7064
# Epoch 6/30, Loss: 52.6553
# Epoch 7/30, Loss: 45.0429
# Epoch 8/30, Loss: 41.2857
# Epoch 9/30, Loss: 37.9990
# Epoch 10/30, Loss: 31.9977
# Epoch 11/30, Loss: 30.9600
# Epoch 12/30, Loss: 26.7861
# Epoch 13/30, Loss: 23.5932
# Epoch 14/30, Loss: 19.5062
# Epoch 15/30, Loss: 18.1995
# Epoch 16/30, Loss: 18.9687
# Epoch 17/30, Loss: 15.6025
# Epoch 18/30, Loss: 12.7435
# Epoch 19/30, Loss: 11.4171
# Epoch 20/30, Loss: 12.1144
# Epoch 21/30, Loss: 8.8913
# Epoch 22/30, Loss: 9.0950
# Epoch 23/30, Loss: 6.2131
# Epoch 24/30, Loss: 6.8407
# Epoch 25/30, Loss: 18.2185
# Epoch 26/30, Loss: 6.1346
# Epoch 27/30, Loss: 3.5244
# Epoch 28/30, Loss: 3.2880
# Epoch 29/30, Loss: 7.8595
# Epoch 30/30, Loss: 3.2597

# %%
torch.save(model.state_dict(), "crnn_mimii_fan.pth")

# %%
# 모델 구조 먼저 다시 선언
model = CRNN(input_shape=(64, mel_data_array.shape[2]), n_classes=2)
model.load_state_dict(torch.load("crnn_mimii_fan.pth"))
model.eval()  # 평가 모드
# Out:
# CRNN(
#   (cnn): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (rnn): LSTM(512, 64, batch_first=True, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
def predict_audio(file_path, model, device="cpu"):
    mel = extract_mel(file_path)  # (64, T)
    
    if mel.shape[1] < 313:
        # 패딩 (너무 짧은 경우)
        pad_width = 313 - mel.shape[1]
        mel = np.pad(mel, ((0, 0), (0, pad_width)), mode='constant')
    elif mel.shape[1] > 313:
        # 자르기 (너무 긴 경우)
        mel = mel[:, :313]
        
    mel_tensor = torch.tensor(mel, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # (1, 1, 64, 313)

    with torch.no_grad():
        output = model(mel_tensor.to(device))
        pred = torch.argmax(output, dim=1).item()
        prob = torch.softmax(output, dim=1).squeeze().cpu().numpy()

    return pred, prob

# %%
normal_count = 0
abnormal_count = 0
total = 0

target_folder = "D:/AI+XDL/archive/dev_data_fan/train"

for filename in os.listdir(target_folder):
    if filename.endswith(".wav"):
        path = os.path.join(target_folder, filename)
        try:
            pred, prob = predict_audio(path, model)
            label = "정상" if pred == 0 else "이상"
            print(f"{filename}: {label} (정상확률: {prob[0]:.3f}, 이상확률: {prob[1]:.3f})")

            if pred == 0:
                normal_count += 1
            else:
                abnormal_count += 1
            total += 1
        except Exception as e:
            print(f"[오류] {filename}: {e}")

# ✅ 예측 결과 통계 출력
if total > 0:
    print("\n🔍 예측 결과 요약:")
    print(f"정상: {normal_count}개 ({normal_count / total * 100:.1f}%)")
    print(f"이상: {abnormal_count}개 ({abnormal_count / total * 100:.1f}%)")
    print(f"총 예측 수: {total}개")
else:
    print("예측된 오디오가 없습니다.")
# Out:
# 00000000.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000001.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000002.wav: 이상 (정상확률: 0.019, 이상확률: 0.981)
# 00000003.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000004.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000005.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000006.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000007.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000008.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000009.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000010.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000011.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000012.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000013.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000014.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000015.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000016.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000017.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000018.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000019.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000020.wav: 이상 (정상확률: 0.013, 이상확률: 0.987)
# 00000021.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000022.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000023.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000024.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000025.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000026.wav: 이상 (정상확률: 0.006, 이상확률: 0.994)
# 00000027.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000028.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000029.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000030.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000031.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000032.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000033.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000034.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000035.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000036.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000037.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000038.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000039.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000040.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000041.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000042.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000043.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000044.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000045.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000046.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000047.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000048.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000049.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000050.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000051.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000052.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000053.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000054.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000055.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000056.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000057.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000058.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000059.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000060.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000061.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000062.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000063.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000064.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000065.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000066.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000067.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000068.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000069.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000070.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000071.wav: 이상 (정상확률: 0.006, 이상확률: 0.994)
# 00000072.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000073.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000074.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000075.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000076.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000077.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000078.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000079.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000080.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000081.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000082.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000083.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000084.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000085.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000086.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000087.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000088.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000089.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000090.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000091.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000092.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000093.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000094.wav: 이상 (정상확률: 0.016, 이상확률: 0.984)
# 00000095.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000096.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000097.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000098.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000099.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000100.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000101.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000102.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000103.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000104.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000105.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000106.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000107.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000108.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000109.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000110.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000111.wav: 이상 (정상확률: 0.010, 이상확률: 0.990)
# 00000112.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000113.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000114.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000115.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000116.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000117.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000118.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000119.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000120.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000121.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000122.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000123.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000124.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000125.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000126.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000127.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000128.wav: 이상 (정상확률: 0.014, 이상확률: 0.986)
# 00000129.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000130.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000131.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000132.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000133.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000134.wav: 이상 (정상확률: 0.017, 이상확률: 0.983)
# 00000135.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000136.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000137.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000138.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000139.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000140.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000141.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000142.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000143.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000144.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000145.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000146.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000147.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000148.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000149.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000150.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000151.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000152.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000153.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000154.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000155.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000156.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000157.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000158.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000159.wav: 이상 (정상확률: 0.019, 이상확률: 0.981)
# 00000160.wav: 이상 (정상확률: 0.009, 이상확률: 0.991)
# 00000161.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000162.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000163.wav: 이상 (정상확률: 0.022, 이상확률: 0.978)
# 00000164.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000165.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000166.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000167.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000168.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000169.wav: 이상 (정상확률: 0.043, 이상확률: 0.957)
# 00000170.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000171.wav: 이상 (정상확률: 0.030, 이상확률: 0.970)
# 00000172.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000173.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000174.wav: 이상 (정상확률: 0.026, 이상확률: 0.974)
# 00000175.wav: 이상 (정상확률: 0.045, 이상확률: 0.955)
# 00000176.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000177.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000178.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000179.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000180.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000181.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000182.wav: 이상 (정상확률: 0.017, 이상확률: 0.983)
# 00000183.wav: 이상 (정상확률: 0.061, 이상확률: 0.939)
# 00000184.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000185.wav: 이상 (정상확률: 0.011, 이상확률: 0.989)
# 00000186.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000187.wav: 이상 (정상확률: 0.043, 이상확률: 0.957)
# 00000188.wav: 이상 (정상확률: 0.320, 이상확률: 0.680)
# 00000189.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000190.wav: 이상 (정상확률: 0.046, 이상확률: 0.954)
# 00000191.wav: 이상 (정상확률: 0.138, 이상확률: 0.862)
# 00000192.wav: 이상 (정상확률: 0.066, 이상확률: 0.934)
# 00000193.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000194.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000195.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000196.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000197.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000198.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000199.wav: 이상 (정상확률: 0.053, 이상확률: 0.947)
# 00000200.wav: 이상 (정상확률: 0.046, 이상확률: 0.954)
# 00000201.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000202.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000203.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000204.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000205.wav: 이상 (정상확률: 0.010, 이상확률: 0.990)
# 00000206.wav: 이상 (정상확률: 0.064, 이상확률: 0.936)
# 00000207.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000208.wav: 이상 (정상확률: 0.020, 이상확률: 0.980)
# 00000209.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000210.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000211.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000212.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000213.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000214.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000215.wav: 이상 (정상확률: 0.027, 이상확률: 0.973)
# 00000216.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000217.wav: 이상 (정상확률: 0.011, 이상확률: 0.989)
# 00000218.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000219.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000220.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000221.wav: 이상 (정상확률: 0.048, 이상확률: 0.952)
# 00000222.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000223.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000224.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000225.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000226.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000227.wav: 이상 (정상확률: 0.009, 이상확률: 0.991)
# 00000228.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000229.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000230.wav: 이상 (정상확률: 0.056, 이상확률: 0.944)
# 00000231.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000232.wav: 이상 (정상확률: 0.011, 이상확률: 0.989)
# 00000233.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000234.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000235.wav: 이상 (정상확률: 0.015, 이상확률: 0.985)
# 00000236.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000237.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000238.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000239.wav: 이상 (정상확률: 0.019, 이상확률: 0.981)
# 00000240.wav: 이상 (정상확률: 0.006, 이상확률: 0.994)
# 00000241.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000242.wav: 이상 (정상확률: 0.013, 이상확률: 0.987)
# 00000243.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000244.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000245.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000246.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000247.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000248.wav: 이상 (정상확률: 0.058, 이상확률: 0.942)
# 00000249.wav: 이상 (정상확률: 0.041, 이상확률: 0.959)
# 00000250.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000251.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000252.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000253.wav: 이상 (정상확률: 0.068, 이상확률: 0.932)
# 00000254.wav: 이상 (정상확률: 0.097, 이상확률: 0.903)
# 00000255.wav: 이상 (정상확률: 0.012, 이상확률: 0.988)
# 00000256.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000257.wav: 이상 (정상확률: 0.219, 이상확률: 0.781)
# 00000258.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000259.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000260.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000261.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000262.wav: 이상 (정상확률: 0.025, 이상확률: 0.975)
# 00000263.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000264.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000265.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000266.wav: 이상 (정상확률: 0.041, 이상확률: 0.959)
# 00000267.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000268.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000269.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000270.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000271.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000272.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000273.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000274.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000275.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000276.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000277.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000278.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000279.wav: 이상 (정상확률: 0.081, 이상확률: 0.919)
# 00000280.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000281.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000282.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000283.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000284.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000285.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000286.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000287.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000288.wav: 이상 (정상확률: 0.043, 이상확률: 0.957)
# 00000289.wav: 이상 (정상확률: 0.007, 이상확률: 0.993)
# 00000290.wav: 이상 (정상확률: 0.044, 이상확률: 0.956)
# 00000291.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000292.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000293.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000294.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000295.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000296.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000297.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000298.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000299.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000300.wav: 이상 (정상확률: 0.006, 이상확률: 0.994)
# 00000301.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000302.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000303.wav: 이상 (정상확률: 0.019, 이상확률: 0.981)
# 00000304.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000305.wav: 이상 (정상확률: 0.114, 이상확률: 0.886)
# 00000306.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000307.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000308.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000309.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000310.wav: 이상 (정상확률: 0.013, 이상확률: 0.987)
# 00000311.wav: 이상 (정상확률: 0.027, 이상확률: 0.973)
# 00000312.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000313.wav: 이상 (정상확률: 0.015, 이상확률: 0.985)
# 00000314.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000315.wav: 이상 (정상확률: 0.043, 이상확률: 0.957)
# 00000316.wav: 이상 (정상확률: 0.064, 이상확률: 0.936)
# 00000317.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000318.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000319.wav: 이상 (정상확률: 0.065, 이상확률: 0.935)
# 00000320.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000321.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000322.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000323.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000324.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000325.wav: 이상 (정상확률: 0.036, 이상확률: 0.964)
# 00000326.wav: 이상 (정상확률: 0.012, 이상확률: 0.988)
# 00000327.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000328.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000329.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000330.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000331.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000332.wav: 이상 (정상확률: 0.017, 이상확률: 0.983)
# 00000333.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000334.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000335.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000336.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000337.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000338.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000339.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000340.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000341.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000342.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000343.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000344.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000345.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000346.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000347.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000348.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000349.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000350.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000351.wav: 이상 (정상확률: 0.066, 이상확률: 0.934)
# 00000352.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000353.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000354.wav: 이상 (정상확률: 0.066, 이상확률: 0.934)
# 00000355.wav: 이상 (정상확률: 0.077, 이상확률: 0.923)
# 00000356.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000357.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000358.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000359.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000360.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000361.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000362.wav: 이상 (정상확률: 0.234, 이상확률: 0.766)
# 00000363.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000364.wav: 이상 (정상확률: 0.013, 이상확률: 0.987)
# 00000365.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000366.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000367.wav: 이상 (정상확률: 0.248, 이상확률: 0.752)
# 00000368.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000369.wav: 이상 (정상확률: 0.034, 이상확률: 0.966)
# 00000370.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000371.wav: 이상 (정상확률: 0.015, 이상확률: 0.985)
# 00000372.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000373.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000374.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000375.wav: 이상 (정상확률: 0.072, 이상확률: 0.928)
# 00000376.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000377.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000378.wav: 이상 (정상확률: 0.005, 이상확률: 0.995)
# 00000379.wav: 이상 (정상확률: 0.011, 이상확률: 0.989)
# 00000380.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000381.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000382.wav: 이상 (정상확률: 0.027, 이상확률: 0.973)
# 00000383.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000384.wav: 이상 (정상확률: 0.115, 이상확률: 0.885)
# 00000385.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000386.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000387.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000388.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000389.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000390.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000391.wav: 이상 (정상확률: 0.125, 이상확률: 0.875)
# 00000392.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000393.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000394.wav: 이상 (정상확률: 0.097, 이상확률: 0.903)
# 00000395.wav: 이상 (정상확률: 0.003, 이상확률: 0.997)
# 00000396.wav: 이상 (정상확률: 0.048, 이상확률: 0.952)
# 00000397.wav: 이상 (정상확률: 0.000, 이상확률: 1.000)
# 00000398.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000399.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000400.wav: 이상 (정상확률: 0.421, 이상확률: 0.579)
# 00000401.wav: 이상 (정상확률: 0.018, 이상확률: 0.982)
# 00000402.wav: 이상 (정상확률: 0.004, 이상확률: 0.996)
# 00000403.wav: 이상 (정상확률: 0.001, 이상확률: 0.999)
# 00000404.wav: 이상 (정상확률: 0.008, 이상확률: 0.992)
# 00000405.wav: 이상 (정상확률: 0.002, 이상확률: 0.998)
# 00000406.wav: 이상 (정상확률: 0.317, 이상확률: 0.683)
#
# 🔍 예측 결과 요약:
# 정상: 0개 (0.0%)
# 이상: 407개 (100.0%)
# 총 예측 수: 407개
